# %%
"""

Check how the model pads input - done
Check how different enecoding & decoding params affect the encoding & decoding - done
todo : check performance of model on a sample set at different batch sizes (inadvertently check how the model performs when padding is present) - till now 1 bs gives best performance

"""

# Autocompletion
# %config Completer.use_jedi = False

# Autoreload
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/workspace/llmsearch')

import awq
import torch
import transformers

import llmsearch

print(awq.__version__, torch.__version__, transformers.__version__, llmsearch.__version__)

import re
import textwrap
from pathlib import Path

import datasets

from awq import AutoAWQForCausalLM
from sklearn.model_selection import GridSearchCV
from transformers import StoppingCriteriaList, AutoTokenizer

from llmsearch.tuner import Tuner
from llmsearch.utils.mem_utils import gc_cuda
from llmsearch.utils.common_utils import json_load, json_dump
from llmsearch.utils.model_downloader import download_model_from_hf
from llmsearch.scripts.stopping_criteria import MultiTokenStoppingCriteria
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.2.4 2.2.0+cu121 4.38.2 0.1.0

# %%
seed = 42
num_samples = 100
model_id = "TheBloke/CapybaraHermes-2.5-Mistral-7B-AWQ"
device = "cuda:0"

# %%
def load_model_and_tokenizer(model_id, temp_model_dir):
    temp_model_dir.mkdir(exist_ok=True, parents=True)
    output_folder = download_model_from_hf(model_id, save_dir=temp_model_dir, branch="main")

    gc_cuda()

    model = AutoAWQForCausalLM.from_quantized(
        quant_path=output_folder, fuse_layers=True, device_map={"": device}, local_files_only=True
    )

    tokenizer = AutoTokenizer.from_pretrained(
        output_folder, local_files_only=True, legacy=False, use_fast=False
    )
    tokenizer.pad_token = tokenizer.unk_token
    tokenizer.padding_side = "left"

    return model, tokenizer

def load_dataset():

    def preprocess_dataset(
        dataset, tokenizer, pt, pt_cols, system_prompt, add_generation_prompt=True
    ):

        def wrapper(sample):
            """Takes in a sample, formats it using prompt template, applies chat template and returns the formatted string"""
            messages = (
                []
                if system_prompt is None
                else [{"role": "system", "content": system_prompt}]
            )
            formatted_pt = pt.format(**{pt_col: sample[pt_col] for pt_col in pt_cols})
            messages.append(
                {
                    "role": "user",
                    "content": formatted_pt,
                }
            )
            formatted_pt_with_ct = tokenizer.apply_chat_template(
                messages, tokenize=False, add_generation_prompt=add_generation_prompt
            )
            return formatted_pt_with_ct

        def actual_input(sample):
            """Takes in a sample, formats it using prompt template, applies chat template and returns the formatted string"""
            return sample[pt_cols[0]]

        pt_dataset = dataset.map(
            lambda sample: {
                "X": wrapper(sample),
                "actual input": actual_input(sample),
            }
        )

        return pt_dataset


    # 2-shot prompt template - https://github.com/EleutherAI/lm-evaluation-harness/blob/main/lm_eval/tasks/gsm8k/gsm8k-cot.yaml
    pt = textwrap.dedent(
    """\
    Q: There are 15 trees in the grove. Grove workers will plant trees in the grove today. After they are done, there will be 21 trees. How many trees did the grove workers plant today?
    A: There are 15 trees originally. Then there were 21 trees after some more were planted. So there must have been 21 - 15 = 6. The answer is 6.

    Q: If there are 3 cars in the parking lot and 2 more cars arrive, how many cars are in the parking lot?
    A: There are originally 3 cars. 2 more cars arrive. 3 + 2 = 5. The answer is 5.

    Q: {question}"""
    )
    pt_cols = ["question"]
    system_prompt = "Solve the following math problems, end with The answer is"
    gsm8k_dataset = datasets.load_dataset("gsm8k", "main")


    processed_dataset = preprocess_dataset(
        gsm8k_dataset["train"],
        tokenizer,
        pt=pt,
        pt_cols=pt_cols,
        system_prompt=system_prompt,
        add_generation_prompt=True,
    )

    shuffled_dataset = processed_dataset.shuffle(seed=seed)

    samples = shuffled_dataset.select(range(num_samples))
    return samples

def get_score(y_true, y_pred):
    def standardize(s):
        if s is None:
            return s
        s = s.replace(",", "")
        if s.endswith("."):
            s = s[:-1]
        return s.strip()

    def extract_answer_from_out(s):
        pattern = re.compile(r"The answer is ((\d|\-)((\d|\,|\.)+)?\d?)")
        match = pattern.search(s)
        if match:
            return match.group(1).strip()
        else:
            return None

    scores = []

    for y_t, y_p in zip(y_true, y_pred):
        y_t_answer = y_t["answer"].split("####")[-1].strip()
        y_p_answer = extract_answer_from_out(y_p)

        y_t_answer = standardize(y_t_answer)
        y_p_answer = standardize(y_p_answer)

        # print("y_pred - ", y_p_answer)
        # print("y_true - ", y_t_answer)

        if y_t_answer == y_p_answer:
            scores.append(1)
        else:
            scores.append(0)
    return sum(scores) / len(scores)

# %%
# Load Model, Tokenizer, Dataset
temp_model_dir = Path(f"./temp_dir/")
temp_model_dir.mkdir(exist_ok=True, parents=True)

model, tokenizer = load_model_and_tokenizer(model_id, temp_model_dir)

# Dataset we will use to find the best generation parameters
samples = load_dataset()

multi_token_stop_criteria_ob = MultiTokenStoppingCriteria(sequence_ids=[32000])
stopping_criteria = StoppingCriteriaList([multi_token_stop_criteria_ob])
callbacks_after_inference = [multi_token_stop_criteria_ob.reset]
# Out:
# Model already exists in temp_dir/TheBloke_CapybaraHermes-2.5-Mistral-7B-AWQ. Checking the model files...
# Checksum validated: model.safetensors  645dfc7f09074aaf25e642f3c6a4f7ea399a0ff2605fa650e4e74078832546de
# Checksum validated: tokenizer.model  dadfd56d766715c61d2ef780a525ab43b8e6da4de6865bda3d95fdef5e134055
# [+] Validated checksums of all model files!
# Replacing layers...: 100%|██████████| 32/32 [00:04<00:00,  6.87it/s]
# Fusing layers...: 100%|██████████| 32/32 [00:02<00:00, 14.41it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import time
from llmsearch.tuner import Tuner
from llmsearch.utils.mem_utils import gc_cuda

batch_size_list = [1, 2, 4, 8, 16, 32]
score_at_diff_batch_sizes = {}

for batch_size in batch_size_list:
    print(f"Batch Size - {batch_size}")

    gc_cuda()

    tuner_ob = Tuner(
        model=model,
        tokenizer=tokenizer,
        dataset=samples,
        device="cuda:0",
        batch_size=batch_size,
        tokenizer_encode_args={"padding": "longest", "add_special_tokens": False},
        tokenizer_decode_args={"spaces_between_special_tokens": False, 'skip_special_tokens' : True},
        scorer=get_score,
        prompt_template="{X}",
        seed=seed,
        column_mapping={"input_cols": ["X"], "eval_cols": ["answer"]},
        callbacks_after_inference=callbacks_after_inference,
    )


    # is stopping criteria cache not being reset properly?
    # check if reset condition is working properly


    gen_params1 = {
        'max_new_tokens' : 500,
        # max_new_tokens take precendece over stopping criteria
        'stopping_criteria' : stopping_criteria,
        'generation_seed' : 42,
    }

    start = time.time()
    scores, outputs = tuner_ob.get_score(gen_params1)
    end = time.time()

    score_at_diff_batch_sizes[batch_size] = {
        'score' : scores,
        'outputs' : outputs,
        'optimal_batch_size' : tuner_ob.estimator._optimal_batch_size,
        'latency_mins' : (end  - start) / 60,
    }

    print(f'score at batch size - {batch_size} - {scores}')
# Out:
# Batch Size - 1
# 100%|██████████| 100/100 [04:09<00:00,  2.50s/it]
# score at batch size - 1 - 0.72
# Batch Size - 2
# 100%|██████████| 50/50 [02:42<00:00,  3.25s/it]
# score at batch size - 2 - 0.65
# Batch Size - 4
# 100%|██████████| 25/25 [01:41<00:00,  4.07s/it]
# score at batch size - 4 - 0.58
# Batch Size - 8
# 100%|██████████| 13/13 [01:08<00:00,  5.27s/it]
# score at batch size - 8 - 0.51
# Batch Size - 16
#   0%|          | 0/7 [00:02<?, ?it/s]
# 100%|██████████| 13/13 [01:08<00:00,  5.26s/it]
# score at batch size - 16 - 0.51
# Batch Size - 32
#   0%|          | 0/4 [00:01<?, ?it/s]
#   0%|          | 0/7 [00:01<?, ?it/s]
# 100%|██████████| 13/13 [01:08<00:00,  5.26s/it]
# score at batch size - 32 - 0.51

# %%
for batch_size in score_at_diff_batch_sizes.keys():
    print(f"Batch Size - {batch_size}")
    print(f"Score - {score_at_diff_batch_sizes[batch_size]['score']}")
    print('\n\n')
# Out:
# Batch Size - 1
# Score - 0.72
#
#
#
# Batch Size - 2
# Score - 0.65
#
#
#
# Batch Size - 4
# Score - 0.58
#
#
#
# Batch Size - 8
# Score - 0.51
#
#
#
# Batch Size - 16
# Score - 0.51
#
#
#
# Batch Size - 32
# Score - 0.51

# %%
for bs_1, bs_2 in zip(score_at_diff_batch_sizes[1]['outputs'], score_at_diff_batch_sizes[2]['outputs']):
    if bs_1 != bs_2:
        print(f"Batch Size - 1 - {bs_1}")
        print(f"Batch Size - 2 - {bs_2}")
        print('\n\n')
# Out:
# Batch Size - 1 - A: Let's break down the information given:
#
# 1. Frankie has 6 more snakes than cats. Let's represent the number of cats as C. So, the number of snakes is C + 6.
# 2. Frankie has one less parrot than cats. So, the number of parrots is C - 1.
# 3. Six of his pets have four legs, which are the dogs.
# 4. He has 2 dogs.
#
# Now, let's find the total number of pets:
#
# 1. C (cats) + (C + 6) (snakes) + (C - 1) (parrots) + 2 (dogs) + 6 (four-legged pets)
# 2. C + C + 6 + C - 1 + 6 + 2
# 3. 4C + 5
#
# Since we know that Frankie has 2 dogs, we can substitute 2 for 6 in the equation:
#
# 4C + 5 = total number of pets
# 4C + 5 = C + 6 + (C - 1) + 2
#
# Now, let's solve for C:
#
# 4C + 5 = 2C + 5 + C + 6 + 2
# 4C - 2C = 13
# 2C = 13
# C = 13/2
# C = 6.5
#
# However, since we can't have a fraction of a pet, we made an assumption that not all pets were accounted for in the given information. In this case, we can conclude that Frankie has at least 6 cats, which means he has 6 + 6 = 12 pets in total (6 snakes and 1 parrot). But remember, this is a minimum number, and there could be more pets. The answer is at least 12.
# Batch Size - 2 - A: Let's use variables to represent the number of each type of pet:
# - Let C be the number of cats.
# - Let S be the number of snakes.
# - Let P be the number of parrots.
#
# We are given the following information:
# 1. S = C + 6 (Frankie has six more snakes than cats)
# 2. P = C - 1 (Frankie has one less parrot than cats)
# 3. There are 6 pets with 4 legs, which are cats (C = 6) and 2 dogs (2).
#
# Now, we can use the information to find the total number of pets:
# 1. From (3), we know that C = 6.
# 2. Substitute C = 6 into (1) to find S: S = 6 + 6 = 12 snakes.
# 3. Substitute C = 6 into (2) to find P: P = 6 - 1 = 5 parrots.
# 4. Now we know the number of each type of pet: 6 cats, 12 snakes, and 5 parrots. We also know there are 2 dogs. So, the total number of pets is 6 + 12 + 5 + 2 = 25. The answer is 25.
#
#
#
# Batch Size - 1 - A: Emma starts with $100 in her account. She spends $8 each day for a week, which is 7 days. So she spends 8 * 7 = $56 during the week. She has $100 - $56 = $44 left in her account. She asks for as many $5 bills as her account can give her, which is $44 / $5 = 8 $5 bills. So she takes out 8 * $5 = $40 from her account. She leaves the remaining $44 - $40 = $4 in her account. The answer is $4.
# Batch Size - 2 - A: Emma starts with $100 in her account. She spends $8 each day for a week, which is 8 * 7 = $56. After spending, she has $100 - $56 = $44 left in her account. She then asks for as many $5 bills as possible, which is $44 / $5 = 8. She leaves the rest, which is $44 - $40 = $4, in her account. The answer is $4.
#
#
#
# Batch Size - 1 - A: On the first day, Ezekiel hiked 10 kilometers. On the second day, he covered half the full hike distance, which is 50 kilometers / 2 = 25 kilometers. So, for the first two days, he hiked 10 + 25 = 35 kilometers. To finish the hike, he had to hike 50 kilometers in total. Therefore, on the third day, he had to hike 50 - 35 = 15 kilometers. The answer is 15.
# Batch Size - 2 - A: Ezekiel hiked 10 kilometers on the first day and half the full hike distance on the second day, which is 50 kilometers / 2 = 25 kilometers. So, on the third day, he had to hike the remaining distance, which is 50 kilometers - 10 kilometers - 25 kilometers = 15 kilometers. The answer is 15.
#
#
#
# Batch Size - 1 - A: The bullseye is worth 50 points. The third dart is worth half the points of the bullseye, so it's worth 50 / 2 = 25 points. The second dart received no points. Adding up the scores, we have 50 + 25 + 0 = 75. The answer is 75.
# Batch Size - 2 - A: Don's first throw is a bullseye worth 50 points. His second throw missed the target, so it received 0 points. His third throw received half the points of the bullseye, which is 50/2 = 25 points. To find the final score, we add up the points from each throw: 50 + 0 + 25 = 75. The answer is 75.
#
#
#
# Batch Size - 1 - A: Pauly has 3 dozen eggs, which is 3 * 12 = 36 eggs. Since there are 3 people and each omelet requires 4 eggs, Pauly can make 36 / 4 = 9 omelets. Each person gets 9 / 3 = 3 omelets. The answer is 3.
# Batch Size - 2 - A: Pauly has 3 dozen eggs, which is 3 * 12 = 36 eggs.
# Each omelet requires 4 eggs, so with all the eggs, Pauly can make 36 / 4 = 9 omelets.
# There are 3 people, so each person gets 9 / 3 = 3 omelets. The answer is 3.
#
#
#
# Batch Size - 1 - A: Let's denote the total number of books as x. We know that 35% of the books are for children, so 65% of the books are for adults (since 100% - 35% = 65%). We are also given that 104 books are for adults. So, we can set up the equation: 0.65x = 104. To find x, we can divide both sides by 0.65: x = 104 / 0.65 = 160. The answer is 160.
# Batch Size - 2 - A: We know that 35% of the books are for children, and there are 104 adult books. Let x be the total number of books. We can set up an equation: 0.35x = 104. To find the total number of books, we can divide both sides by 0.35: x = 104 / 0.35 ≈ 300. The answer is approximately 300 books in the library.
#
#
#
# Batch Size - 1 - A: Nicky trades two cards worth $8 each, so the total value of the cards he trades is 2 * $8 = $16. He receives a card worth $21 in return. So, his profit is the difference between the value of the card he received and the value of the cards he traded, which is $21 - $16 = $5. The answer is $5.
# Batch Size - 2 - A: Nicky starts with 2 cards worth $8 each, so he has 2 * $8 = $16 in total. After trading, he has 1 card worth $21. So, he makes a profit of $21 - $16 = $5. The answer is $5.
#
#
#
# Batch Size - 1 - First, let's find out how much Niko spent on the 9 pairs of socks: 9 pairs * $2 per pair = $18.
#
# For the 4 pairs of socks where he wants a 25% profit, let's find out how much profit he wants to make: $18 * 0.25 = $4.5.
#
# Now, let's find out the original price of these 4 pairs of socks: $18 - $4.5 = $13.5.
#
# To make a 25% profit, he will sell these 4 pairs for 1.25 times the original price: $13.5 * 1.25 = $16.875.
#
# For the other 5 pairs of socks, he wants to make an extra $0.2 per pair. So, the total profit for these 5 pairs will be: 5 pairs * $0.2 = $1.
#
# Now, let's find out the selling price for each of these 5 pairs: $2 original price + $0.2 = $2.2.
#
# Now, let's calculate the total profit from these 5 pairs: 5 pairs * $2.2 - $1 = $10.
#
# Finally, let's find out the total profit from selling all 9 pairs: $16.875 (from 4 pairs) + $10 (from 5 pairs) = $26.875.
#
# The answer is $26.875.
# Batch Size - 2 - First, let's find out how much Niko paid for the 9 pairs of socks in total: 9 pairs * $2 per pair = $18.
#
# For the 4 pairs of socks, Niko wants a 25% profit, which means he wants to make an additional $18 * 0.25 = $4.50 profit on each of these pairs. So, he will sell these 4 pairs for $2 + $4.50 = $6.50 each.
#
# The total amount he will make from selling these 4 pairs is 4 pairs * $6.50 per pair = $26.
#
# For the other 5 pairs of socks, he wants to make an additional $0.20 profit each, which means he will sell these 5 pairs for $2 + $0.20 = $2.20 each.
#
# The total amount he will make from selling these 5 pairs is 5 pairs * $2.20 per pair = $11.
#
# Now, let's find out his total profit: $26 (from the 4 pairs) + $11 (from the 5 pairs) = $37.
#
# The answer is $37.
#
#
#
# Batch Size - 1 - A: The number of short students is 2/5 of the total number of students, which is 2/5 * 400 = 160 students.
# The total number of students with average height is the difference between the total number of students and the number of tall students, which is 400 - 90 = 310 students. The answer is 310.
# Batch Size - 2 - A: The number of short students is 2/5 of the total number of students, which is 2/5 * 400 = 160 short students.
# The total number of students with average height is the difference between the total number of students and the number of tall students, which is 400 - 90 = 310 students. The answer is 310.
#
#
#
# Batch Size - 1 - A: Tonya made $50 in total. She sold $11 worth of small lemonades and $24 worth of medium lemonades. So, the revenue from small and medium lemonades is $11 + $24 = $35.
#
# Since large lemonades are sold at $3 each, to find out how many large lemonades she sold, we need to find out how much revenue she made from large lemonades. So, the revenue from large lemonades is $50 - $35 = $15.
#
# Since each large lemonade is sold at $3, to find out how many large lemonades she sold, we divide the revenue from large lemonades by the price of a large lemonade: $15 / $3 = 5.
#
# The answer is 5 large lemonades.
# Batch Size - 2 - A: Tonya sold $11 worth of small lemonades and $24 worth of medium lemonades. Since small lemonades cost $1 each and medium lemonades cost $2 each, she sold a total of ($11 + $24) / $2 = $35 worth of small and medium lemonades.
#
# She ended up making $50, so the revenue from large lemonades is $50 - $35 = $15. Since large lemonades cost $3 each, she sold $15 / $3 = 5 cups of large lemonade. The answer is 5.
#
#
#
# Batch Size - 1 - A: Leo finished the first part in 25 minutes. The second part took him twice as long, so it took 25 * 2 = 50 minutes. The total time for the first two parts is 25 + 50 = 75 minutes. Since he finished his assignment in 2 hours, which is 2 * 60 = 120 minutes, the time he took for the third part is 120 - 75 = 45 minutes. The answer is 45.
# Batch Size - 2 - A: Leo finished the first part in 25 minutes. The second part took him twice as long, so it took 25 * 2 = 50 minutes. The total time for the first two parts is 25 + 50 = 75 minutes. Since he finished his assignment in 2 hours, which is 2 * 60 = 120 minutes, the time he spent on the third part is 120 - 75 = 45 minutes. The answer is 45.
#
#
#
# Batch Size - 1 - A: First, find the number of red beans: 572 * (1/4) = 143 red beans.
# Then, subtract the red beans from the total: 572 - 143 = 429 beans remaining.
# Next, find the number of white beans: 429 * (1/3) = 143 white beans.
# Then, subtract the red and white beans from the total: 429 - 143 - 143 = 143 beans remaining.
# Finally, these 143 beans are the green beans. The answer is 143.
# Batch Size - 2 - First, let's find out how many red beans there are: 572 beans * 1/4 = 143 red beans.
#
# Next, let's find out how many beans are left after taking out the red beans: 572 beans - 143 red beans = 429 beans.
#
# Now, let's find out how many white beans there are: 429 beans * 1/3 = 143 white beans.
#
# Then, let's find out how many beans are left after taking out the red and white beans: 429 beans - 143 red beans - 143 white beans = 0 beans.
#
# Since there are no beans left, there are no green beans. The answer is 0.
#
#
#
# Batch Size - 1 - A: Wendy lived for 80 years. She spent 25 years as an accountant and 15 years as an accounting manager. So, she spent a total of 25 + 15 = 40 years in an accounting-related job. To find the percentage, we can divide the number of years she spent in an accounting-related job by her total lifespan and multiply by 100: (40 / 80) * 100 = 50%. The answer is 50%.
# Batch Size - 2 - A: Wendy spent a total of 25 + 15 = 40 years in accounting-related jobs. She lived to be 80 years old. To find the percentage, we can divide the years spent in accounting-related jobs by her total lifespan and multiply by 100: (40 / 80) * 100 = 50%. The answer is 50%.
#
#
#
# Batch Size - 1 - A: Dulce's father has 8 orange trees, and each tree has 200 fruits. So there are 8 * 200 = 1600 oranges in total. Dulce picks 2/5 of the oranges from each tree, which is 2/5 * 200 = 80 oranges per tree. Since there are 8 trees, Dulce picks a total of 80 * 8 = 640 oranges. To find the remaining oranges, subtract the picked oranges from the total: 1600 - 640 = 960. The answer is 960.
# Batch Size - 2 - A: Dulce's father has 8 orange trees, and each tree has 200 fruits. So there are 8 * 200 = 1600 oranges in total. Dulce picks 2/5 of the oranges from each tree, which is 2/5 * 200 = 80 oranges per tree. Since there are 8 trees, Dulce picks a total of 80 * 8 = 640 oranges. To find the remaining oranges, subtract the picked oranges from the total oranges: 1600 - 640 = 960. The answer is 960.
#
#
#
# Batch Size - 1 - A: Padma traded 2 of her valuable cards for 10 of Robert's cards, so that's 2 + 10 = 12 cards traded. Robert traded 8 of his cards for 15 of Padma's cards, so that's 8 + 15 = 23 cards traded. In total, they traded 12 + 23 = 35 cards between both Padma and Robert. The answer is 35.
# Batch Size - 2 - A: Padma traded 2 of her valuable cards for 10 of Robert's cards, so that's 2 + 10 = 12 cards traded by Padma.
# Robert traded 8 of his cards for 15 of Padma's cards, so that's 8 + 15 = 23 cards traded by Robert.
# In total, they traded 12 (Padma) + 23 (Robert) = 35 cards between both Padma and Robert. The answer is 35.
#
#
#
# Batch Size - 1 - A: First, find the number of deer with 8 antlers: 920 * 10% = 92 deer. Then, find the number of those deer that also have albino fur: 92 * 25% = 23 albino 8-antlered deer. The answer is 23.
# Batch Size - 2 - A: First, find the number of deer with 8 antlers: 920 * 10% = 920 * 0.1 = 92 deer. Then, find the number of albino 8-antlered deer: 92 * 25% = 92 * 0.25 = 23 albino deer. The answer is 23.
#
#
#
# Batch Size - 1 - A: The game promises 100 hours of gameplay, but 80% of that is boring grinding. So, 80% of 100 hours is 0.8 * 100 = 80 hours of boring grinding. The expansion adds another 30 hours of enjoyable gameplay. So, to find out how much enjoyable gameplay James gets, we subtract the boring grinding hours from the total gameplay hours: 100 - 80 = 20 hours. The answer is 20.
# Batch Size - 2 - A: The game promises 100 hours of gameplay, but 80% of that is boring grinding. So, 80% of 100 hours is (0.8) * 100 = 80 hours of boring grinding. The expansion adds 30 hours of enjoyable gameplay. Since James doesn't play the boring grinding, he only has the 30 hours of enjoyable gameplay from the expansion. The answer is 30.
#
#
#
# Batch Size - 1 - A: Peter spends $3 for each small glass and buys 8 small glasses, so he spends 8 * $3 = $24 on small glasses. He has $50 initially and receives $1 in change, so he spent $50 - $1 = $49. Since he spent $24 on small glasses, he spent the remaining $49 - $24 = $25 on large glasses. Each large glass costs $5, so he bought $25 / $5 = 5 large glasses. The answer is 5.
# Batch Size - 2 - First, let's find out how much Peter spent on small glasses: 8 small glasses * $3 per small glass = $24.
#
# Since Peter has $50 initially and received $1 in change, he spent $50 - $1 = $49.
#
# Now, we know that Peter spent $49 on small glasses and large glasses. So, to find out how much he spent on large glasses, we subtract the amount spent on small glasses from the total amount spent: $49 - $24 = $25.
#
# Since large glasses cost $5 each, we can find out how many large glasses Peter bought by dividing the amount spent on large glasses by the cost of a large glass: $25 / $5 = 5 large glasses.
#
# The answer is 5 large glasses.
#
#
#
# Batch Size - 1 - A: First, we need to find the monthly payments for both the house and the trailer.
#
# For the house, the total cost is $480,000 and the loan term is 20 years (240 months). So, the monthly payment for the house is $480,000 / 240 = $2,000.
#
# For the trailer, the total cost is $120,000 and the loan term is also 20 years (240 months). So, the monthly payment for the trailer is $120,000 / 240 = $500.
#
# Now, we can find the difference in monthly payments: $2,000 (house) - $500 (trailer) = $1,500.
#
# The answer is $1,500 more in monthly payments for the house compared to the trailer.
# Batch Size - 2 - A: First, we need to find the monthly payments for each option. For the house, the total cost is $480,000 and the loan term is 20 years (240 months). So, the monthly payment for the house is $480,000 / 240 = $2,000.
#
# For the trailer, the total cost is $120,000 and the loan term is also 20 years (240 months). So, the monthly payment for the trailer is $120,000 / 240 = $500.
#
# Now, we can find the difference in monthly payments by subtracting the trailer's payment from the house's payment: $2,000 - $500 = $1,500.
#
# The answer is $1,500 more for the monthly payment on the house compared to the trailer.
#
#
#
# Batch Size - 1 - A: Clare had $47 initially. She bought 4 loaves of bread, which cost 4 * $2 = $8. She also bought 2 cartons of milk, which cost 2 * $2 = $4. So, the total cost of her purchases is $8 + $4 = $12. To find out how much money Clare has left, subtract the cost of her purchases from the initial amount: $47 - $12 = $35. The answer is $35.
# Batch Size - 2 - A: Clare had $47 initially. She bought 4 loaves of bread, which cost 4 * $2 = $8. She also bought 2 cartons of milk, which cost 2 * $2 = $4. So, the total cost of her purchases was $8 + $4 = $12. To find out how much money Clare has left, subtract the cost of her purchases from the initial amount: $47 - $12 = $35. The answer is $35.
#
#
#
# Batch Size - 1 - A: Eric originally had 150 colored pencils. Then 30 more pencils were added. So he has 150 + 30 = 180 pencils. He wants to evenly distribute these pencils into 5 containers. To find out how many pencils each container will have, we divide the total number of pencils by the number of containers: 180 / 5 = 36. The answer is 36.
# Batch Size - 2 - A: Eric originally had 150 colored pencils. Then, 30 more pencils were added. So, he now has 150 + 30 = 180 colored pencils. He wants to distribute these evenly between 5 containers. To find out how many pencils each container will have, we divide the total number of pencils by the number of containers: 180 ÷ 5 = 36. The answer is 36 colored pencils in each container.
#
#
#
# Batch Size - 1 - A: The first 100 channels cost $100. The next 100 channels cost half as much, which is $100/2 = $50. So, the total cost for all 200 channels is $100 + $50 = $150. Since James splits the cost evenly with his roommate, he pays half of the total cost, which is $150/2 = $75. The answer is $75.
# Batch Size - 2 - A: The first 100 channels cost $100. The next 100 channels cost half as much, which is $100 / 2 = $50. So, the total cost for all 200 channels is $100 + $50 = $150. Since James splits the cost evenly with his roommate, he pays half of $150, which is $150 / 2 = $75. The answer is $75.
#
#
#
# Batch Size - 1 - A: The sprinkler system uses 4 liters in the morning and 6 liters in the evening, for a total of 4 + 6 = 10 liters per day. To use 50 liters of water, it would take 50 / 10 = 5 days. The answer is 5.
# Batch Size - 2 - A: The sprinkler system uses 4 liters in the morning and 6 liters in the evening. So, it uses a total of 4 + 6 = 10 liters per day. To use 50 liters, it will take 50 / 10 = 5 days. The answer is 5.
#
#
#
# Batch Size - 1 - A: John spends $850 and gets $40 in change. So, the total cost of the 3 barbells is $850 - $40 = $810. To find the cost of each barbell, divide the total cost by the number of barbells: $810 / 3 = $270. The answer is $270.
# Batch Size - 2 - A: John buys 3 barbells for a total of $850. He receives $40 in change. This means he paid $850 - $40 = $410 for the 3 barbells. To find the cost of each barbell, we divide the total cost by the number of barbells: $410 / 3 = $13.33. The answer is $13.33.
#
#
#
# Batch Size - 1 - A: Wilson sleds down each of the 2 tall hills 4 times, so that's 2 * 4 = 8 times. He sleds down the tall hills 8 times, and he sleds down the small hills half as often, which is 8 / 2 = 4 times per small hill. There are 3 small hills, so he sleds down each small hill 4 times, which is 3 * 4 = 12 times. In total, he sleds down the hills 8 (tall hills) + 12 (small hills) = 20 times. The answer is 20.
# Batch Size - 2 - A: Wilson sleds down each of the 2 tall hills 4 times, so that's 2 * 4 = 8 times. On the 3 small hills, he sleds down half as often as the tall hills, which is 4 / 2 = 2 times per small hill. So, he sleds down each small hill 2 times, which is a total of 3 * 2 = 6 times. In total, Wilson sleds down the hills 8 (tall hills) + 6 (small hills) = 14 times. The answer is 14.
#
#
#
# Batch Size - 1 - A: Let's assume the number of cans of orange pop is x. Since there are twice as many cans of orange pop as there are cherry sodas, we have x = 2 * (number of cherry sodas). The total number of cans is 24 (cherry sodas + orange pop). So, we have the equation: x + (number of cherry sodas) = 24.
#
# Substitute x = 2 * (number of cherry sodas) into the equation: 2 * (number of cherry sodas) + (number of cherry sodas) = 24.
#
# Combine the terms: 3 * (number of cherry sodas) = 24.
#
# Now, divide both sides by 3: (number of cherry sodas) = 24 / 3.
#
# The number of cherry sodas is 8. The answer is 8.
# Batch Size - 2 - Twice as many cans of orange pop as there are of cherry soda means there are 2 cans of orange pop. So there are 2 cans of cherry soda and 4 cans of orange pop. The answer is 4 cans of cherry soda.
#
#
#
# Batch Size - 1 - A: First, convert Connor's study time to minutes: 1.5 hours * 60 minutes/hour = 90 minutes.
# Now, add Kwame's and Connor's study times: 2.5 hours + 1.5 hours = 4 hours. Then convert it to minutes: 4 hours * 60 minutes/hour = 240 minutes.
# Next, add Lexia's study time: 240 minutes + 90 minutes + 97 minutes = 327 minutes.
# Finally, find the difference between their study times: 327 minutes - 97 minutes = 230 minutes.
# The answer is 230.
# Batch Size - 2 - A: Kwame studied for 2.5 hours, which is equal to 2.5 * 60 = 150 minutes. Connor studied for 1.5 hours, which is equal to 1.5 * 60 = 90 minutes. Lexia studied for 97 minutes. To find out how many minutes more Kwame and Connor studied than Lexia, we need to calculate the difference: (150 + 90) - 97 = 243 - 97 = 146 minutes. The answer is 146.
#
#
#
# Batch Size - 1 - A: First, we find Jordyn's age, which is double Zrinka's age. Since Zrinka is 6 years old, Jordyn is 2 * 6 = 12 years old. Then, we find Mehki's age, which is 10 years older than Jordyn's age. So, Mehki is 12 + 10 = 22 years old. The answer is 22.
# Batch Size - 2 - A: Zrinka is 6 years old. Jordyn's age is double Zrinka's age, so Jordyn is 6 * 2 = 12 years old. Mehki is 10 years older than Jordyn, so Mehki is 12 + 10 = 22 years old. The answer is 22.
#
#
#
# Batch Size - 1 - A: First, we need to find out how many half-gallons of milk are needed for one dozen cookies. To do this, we divide the total half-gallons needed for 40 cookies (10 half-gallons) by 40: 10 / 40 = 0.25 half-gallons per dozen cookies.
#
# Now, we need to find out how many half-gallons of milk are needed for 200 dozen cookies. To do this, we multiply the half-gallons per dozen cookies (0.25) by 200: 0.25 * 200 = 50 half-gallons.
#
# The answer is 50.
# Batch Size - 2 - A: First, we need to find out how many half-gallons of milk are needed for one dozen cookies. To do this, we divide the total half-gallons needed for 40 cookies (10 half-gallons) by 40: 10 / 40 = 0.25 half-gallons per dozen cookies.
#
# Now, we need to find out how many half-gallons of milk are needed for 200 dozen cookies. To do this, we multiply the half-gallons per dozen cookies (0.25) by 200: 0.25 * 200 = 50 half-gallons.
#
# The answer is 50 half-gallons of milk.
#
#
#
# Batch Size - 1 - In the first year, Adam teaches 40 students. For the remaining 9 years, he teaches 50 students each year. So, in 9 years, he teaches 9 * 50 = 450 students. Adding the 40 students from the first year, Adam will teach a total of 450 + 40 = 490 students in 10 years. The answer is 490.
# Batch Size - 2 - A: In the first year, Adam teaches 40 students. If he teaches the same number of students each year, he will teach 40 students in the first year, 40 students in the second year, and so on. So, in 10 years, he will teach 40 + 40 + 40 + 40 + 40 + 40 + 40 + 40 + 40 + 40 = 400 students. The answer is 400.
#
#
#
# Batch Size - 1 - A: Dave bought 3 packs of white T-shirts, which is 3 * 6 = 18 white T-shirts. He also bought 2 packs of blue T-shirts, which is 2 * 4 = 8 blue T-shirts. In total, Dave bought 18 + 8 = 26 T-shirts. The answer is 26.
# Batch Size - 2 - A: Dave bought 3 packs of white T-shirts, each with 6 T-shirts, so he bought 3 * 6 = 18 white T-shirts. He also bought 2 packs of blue T-shirts, each with 4 T-shirts, so he bought 2 * 4 = 8 blue T-shirts. In total, Dave bought 18 (white) + 8 (blue) = 26 T-shirts. The answer is 26.
#
#
#
# Batch Size - 1 - A: Carla caught 8 fish. Since Kyle and Tasha caught the same number of fish together, and the total number of fish caught by all three is 36, we can subtract Carla's catch from the total: 36 - 8 = 28. Since Kyle and Tasha caught the same number of fish, we can divide the remaining fish by 2 to find out how many fish Kyle caught: 28 / 2 = 14. The answer is 14.
# Batch Size - 2 - A: Carla caught 8 fish. Since Kyle and Tasha caught the same number of fish, together they caught 36 - 8 = 28 fish. Since they caught the same number of fish, each of them caught 28 / 2 = 14 fish. The answer is 14.
#
#
#
# Batch Size - 1 - A: Miss Davis gave away 15 sticks to each of the 10 groups, so she gave away a total of 15 * 10 = 150 popsicle sticks. She started with 170 sticks, so after giving away 150 sticks, she has 170 - 150 = 20 popsicle sticks left. The answer is 20.
# Batch Size - 2 - A: Miss Davis gave away a total of 15 sticks per group to 10 groups, which is 15 * 10 = 150 sticks. She started with 170 sticks, so after giving away 150 sticks, she has 170 - 150 = 20 sticks left. The answer is 20.
#
#
#
# Batch Size - 1 - A: Each t-shirt is originally $20 and is 50% off, so the discount is $20 * 0.5 = $10 per t-shirt. Since James buys 6 t-shirts, the total amount he pays is 6 * $10 = $60. The answer is $60.
# Batch Size - 2 - A: First, we need to find the discounted price of each t-shirt. At 50% off, each t-shirt costs $20 * 0.5 = $10. James buys 6 t-shirts at $10 each, so he pays 6 * $10 = $60. The answer is $60.
#
#
#
# Batch Size - 1 - A: Initially, there are 9 blue pens, 21 black pens, and 6 red pens, for a total of 9 + 21 + 6 = 36 pens. After removing 4 blue pens, there are 9 - 4 = 5 blue pens left. After removing 7 black pens, there are 21 - 7 = 14 black pens left. So, there are 5 blue pens + 14 black pens + 6 red pens = 25 pens left in the jar. The answer is 25.
# Batch Size - 2 - A: Initially, there are 9 blue pens, 21 black pens, and 6 red pens, for a total of 9 + 21 + 6 = 36 pens. After removing 4 blue pens and 7 black pens, there are 36 - 4 - 7 = 25 pens left in the jar. The answer is 25.
#
#
#
# Batch Size - 1 - A: The eldest child is 20 years old now. The second child is 20 - 5 = 15 years old. The third child is 15 - 5 = 10 years old. In 10 years, the eldest will be 20 + 10 = 30 years old, the second will be 15 + 10 = 25 years old, and the third will be 10 + 10 = 20 years old. The total of their ages 10 years from now is 30 + 25 + 20 = 75. The answer is 75.
# Batch Size - 2 - A: The eldest child is 20 years old now. Since the siblings are born 5 years apart, the second child is 20 - 5 = 15 years old. The third child is 15 - 5 = 10 years old. In 10 years, the eldest child will be 20 + 10 = 30 years old. The second child will be 15 + 10 = 25 years old. The third child will be 10 + 10 = 20 years old. The total of their ages 10 years from now will be 30 + 25 + 20 = 75. The answer is 75.
#
#
#
# Batch Size - 1 - A: If Neil had 7 games at first and then received 6 games from Henry, he has 7 + 6 = 13 games now. Since Henry has 4 times more games than Neil, Henry had 4 * 13 = 52 games at first. The answer is 52.
# Batch Size - 2 - A: If Neil had 7 games at first and he received 6 games from Henry, then Neil has 7 + 6 = 13 games after receiving the games from Henry. Since Henry now has 4 times more games than Neil, that means Henry has 4 * 13 = 52 games. The answer is 52.
#
#
#
# Batch Size - 1 - A: Sarah initially has 9 cupcakes. She saves a third of them, which is 9/3 = 3 cupcakes. She gives these 3 cupcakes to Michael. So, Sarah ends up with her initial 9 cupcakes minus the 3 cupcakes she gave to Michael, which is 9 - 3 = 6 cupcakes. Additionally, Sarah receives 5 cookies from Michael. So, Sarah ends up with 6 cupcakes + 5 cookies = 11 desserts. The answer is 11.
# Batch Size - 2 - A: Sarah initially has 9 cupcakes. She saves a third of them, which is 9 * (1/3) = 3 cupcakes, to give to Michael. So, she ends up with 9 - 3 = 6 cupcakes.
#
# Michael initially has 5 cookies. He receives 3 cupcakes from Sarah. So, he ends up with 5 + 3 = 8 desserts (5 cookies + 3 cupcakes).
#
# The question asks for the number of desserts Sarah ends up with, so the answer is 6 cupcakes.
#
#
#
# Batch Size - 1 - First, find out how many students will move to the new school: 1590 students * 40% = 636 students.
#
# Next, find out how many students will be in each grade level at the new school: 636 students / 3 grade levels = 212 students per grade level.
#
# Now, find out how many students will be in the advanced class: 20 students per advanced class * 3 grade levels = 60 students.
#
# Subtract the number of students in the advanced classes from the total number of students to find out how many students will be in the normal classes: 212 students per grade level - 60 students = 152 students per grade level.
#
# Since there are 6 additional classes per grade level, divide the remaining students by the number of classes: 152 students / 6 classes = 25 students per normal class.
#
# The answer is 25 students per normal class at the new school.
# Batch Size - 2 - First, let's find out how many students will move to the new school: 1590 students * 40% = 1590 * 0.4 = 636 students.
#
# Now, there are 3 grade levels, so there will be 3 advanced classes and 3 additional classes. Each advanced class has 20 students, so there will be 3 * 20 = 60 students in the advanced classes.
#
# The remaining students will be distributed evenly into the 3 additional classes. So, there are 636 - 60 = 636 - 60 = 636 students - 20 students per class = 636 / 3 = 210 students per additional class.
#
# Since there are 3 additional classes, there will be 210 students per additional class. The answer is 210.
#
#
#
# Batch Size - 1 - A: Richard takes 22 minutes to clean his room. Cory takes 3 minutes more, so she takes 22 + 3 = 25 minutes. Blake takes 4 minutes less than Cory, so he takes 25 - 4 = 21 minutes.
#
# They each clean their rooms twice a week, so in a week, Richard spends 22 * 2 = 44 minutes, Cory spends 25 * 2 = 50 minutes, and Blake spends 21 * 2 = 42 minutes.
#
# Together, all three spend 44 + 50 + 42 = 136 minutes cleaning their rooms each week. The answer is 136.
# Batch Size - 2 - A: Richard takes 22 minutes to clean his room. Cory takes 22 + 3 = 25 minutes. Blake takes 25 - 4 = 21 minutes. They clean their rooms twice a week, so each week they spend:
#
# Richard: 22 * 2 = 44 minutes
# Cory: 25 * 2 = 50 minutes
# Blake: 21 * 2 = 42 minutes
#
# Total time spent cleaning their rooms each week: 44 + 50 + 42 = 136 minutes. The answer is 136.
#
#
#
# Batch Size - 1 - A: Let's denote the first number as x. Since the second number is twice the first number, the second number is 2x. The sum of the two numbers is 33, so we can write the equation x + 2x = 33. Combining the terms, we get 3x = 33. To find the value of x, we divide both sides by 3: x = 33/3 = 11. The second number is 2x, which is 2 * 11 = 22. The answer is 22.
# Batch Size - 2 - Let the first number be x. Since the second number is twice the first number, the second number is 2x. The sum of the two numbers is 33, so we can write the equation x + 2x = 33. Combining the terms, we get 3x = 33. To find the first number (x), we divide both sides by 3: x = 33/3 = 11. The second number is 2x, which is 2 * 11 = 22. The answer is 22.
#
#
#
# Batch Size - 1 - A: Each jug holds 5 liters of water. So, 4 jugs hold 4 * 5 = 20 liters of water. Since a bucket holds 4 jugs, 2 buckets hold 2 * 20 = 40 liters of water. The answer is 40.
# Batch Size - 2 - A: There are 5 liters of water in one jug. So, there are 5 * 4 = 20 liters of water in 4 jugs. If 2 buckets contain these 4 jugs, then there are 20 * 2 = 40 liters of water in 2 buckets. The answer is 40.
#
#
#
# Batch Size - 1 - A: The first staircase has 20 steps. The second staircase has twice as many steps, so it has 20 * 2 = 40 steps. The final staircase has 10 fewer steps, so it has 40 - 10 = 30 steps. The total number of steps John climbed is 20 + 40 + 30 = 90 steps. Since each step is 0.5 feet, John climbed 90 * 0.5 = 45 feet. The answer is 45.
# Batch Size - 2 - A: The first staircase has 20 steps. The next staircase has twice as many steps, so it has 20 * 2 = 40 steps. The final staircase has 10 fewer steps, so it has 40 - 10 = 30 steps.
#
# In total, John climbs 20 + 40 + 30 = 90 steps. Since each step is 0.5 feet, John climbs 90 * 0.5 = 45 feet. The answer is 45.
#
#
#
# Batch Size - 1 - A: First, we need to find out how many pearls Jamie collects per dive. Since 25% of oysters have pearls, Jamie collects 25% of 16 oysters, which is 0.25 * 16 = 4 pearls per dive.
#
# Next, we need to find out how many dives are required to collect 56 pearls. To do this, we divide the total number of pearls needed (56) by the number of pearls collected per dive (4): 56 / 4 = 14 dives.
#
# The answer is 14.
# Batch Size - 2 - A: Each oyster has a 25% chance of having a pearl. So, to collect 1 pearl, Jamie needs to open 1 / 0.25 = 4 oysters.
#
# To collect 56 pearls, Jamie needs to open 56 / 1 = 56 oysters.
#
# Since he can collect 16 oysters per dive, he needs to make 56 / 16 = 3.5 dives.
#
# However, since he can't make half a dive, Jamie needs to make 4 dives to collect 56 pearls, as the 4th dive will collect the remaining 16 - 12 = 4 oysters with pearls. The answer is 4.
#
#
#
# Batch Size - 1 - A: Susan eats 1 strawberry out of every handful of 5. So for each handful, she actually puts 5 - 1 = 4 strawberries into her basket. To fill her basket with 60 strawberries, she needs to pick 60 / 4 = 15 handfuls of strawberries. In each handful, there are 5 strawberries, so she will actually pick 15 * 5 = 75 strawberries before her basket is full. The answer is 75.
# Batch Size - 2 - A: For every 5 strawberries, Susan eats 1, so she effectively picks 5 strawberries each time. Since her basket holds 60 strawberries, she needs to pick enough handfuls to reach 60 strawberries. So, she picks 60 / 5 = 12 handfuls of strawberries. In each handful, she picks 5 strawberries, so she actually picks 12 * 5 = 60 strawberries. The answer is 60.
#
#
#
# Batch Size - 1 - First, let's find out how much John spends on 15 packets of chips: 15 packets * $2 per packet = $30.
#
# Now, John has $45 - $30 = $15 left for corn chips.
#
# Since corn chips cost $1.5 per packet, we can find out how many packets of corn chips John can buy with the remaining $15: $15 / $1.5 per packet = 10 packets.
#
# The answer is 10.
# Batch Size - 2 - First, let's find out how much John spends on 15 packets of chips: 15 packets * $2 per packet = $30.
#
# Now, John has $45 - $30 = $15 left for corn chips.
#
# Since corn chips cost $1.5 per packet, we can find out how many packets of corn chips John can buy with the remaining $15: $15 / $1.5 per packet = 10 packets.
#
# The answer is 10 packets of corn chips.
#
#
#
# Batch Size - 1 - A: James starts with 5 oranges, each containing 80 calories. So, he has a total of 5 * 80 = 400 calories. He then splits these 400 calories between 4 people. To find out how many calories each person gets, we divide the total calories by the number of people: 400 / 4 = 100 calories. The answer is 100.
# Batch Size - 2 - A: James takes 5 oranges and breaks each into 8 pieces, so he has a total of 5 * 8 = 40 pieces. He splits these pieces between 4 people, so each person gets 40 / 4 = 10 pieces. Since each orange has 80 calories, and each person gets 10 pieces, each person gets 80 * 10 = 800 calories. The answer is 800.
#
#
#
# Batch Size - 1 - A: The vampire drains 3 people per week, and the werewolf eats 5 people per week. Together, they consume 3 + 5 = 8 people per week. If there are 72 people in the village, we can find out how many weeks it will last them by dividing the total number of people by the number of people they consume per week: 72 / 8 = 9. The answer is 9 weeks.
# Batch Size - 2 - A: The vampire drains 3 people per week, and the werewolf eats 5 people per week. Together, they consume 3 + 5 = 8 people per week. They have a total of 72 people in the village. To find out how many weeks the village will last them, divide the total number of people by the combined consumption rate: 72 / 8 = 9. The answer is 9 weeks.
#
#
#
# Batch Size - 1 - A: Miriam can take care of 60 flowers in one day. She works for 6 days. So, she can take care of 60 * 6 = 360 flowers. The answer is 360.
# Batch Size - 2 - A: Miriam can take care of 60 flowers in one day. She works 6 days. So, she can take care of 60 * 6 = 360 flowers in 6 days of work. The answer is 360.
#
#
#
# Batch Size - 1 - A: The magician works 3 hours every day for 2 weeks. So, there are 3 hours/day * 7 days/week * 2 weeks = 42 hours in total. At $60 per hour, Stan pays the magician 42 hours * $60/hour = $2520. The answer is $2520.
# Batch Size - 2 - A: The magician is paid $60 per hour and works 3 hours every day. So, the magician works 3 * $60 = $180 per day. Since there are 2 weeks, Stan works with the magician for 2 * 7 = 14 days. Therefore, Stan pays the magician 14 * $180 = $2520. The answer is $2520.

# %%
# pad token = eos token
# padding side - left

for output in score_at_diff_batch_sizes[1]['outputs']:
    print(output)
for batch_size in score_at_diff_batch_sizes.keys():
    print(f"Batch Size - {batch_size}")
    print(f"Score - {score_at_diff_batch_sizes[batch_size]['score']}")
    print('\n\n')

# %%
# print out the results

# proves that llmsearch should be run on a batch size of 1

for batch_size, score_dict in score_at_diff_batch_sizes.items():
    print(f"Batch Size - {batch_size}")
    print(f"Score - {score_dict['score']}")
    print(f"Latency - {score_dict['latency_mins']} mins")
    print(f"Optimal Batch Size - {score_dict['optimal_batch_size']}")
    print("\n\n")

# %%
score_at_diff_batch_sizes

# %%
score_at_diff_batch_sizes[batch_size] = {
        'score' : scores,
        'outputs' : outputs,
        'optimal_batch_size' : tuner_ob.estimator._optimal_batch_size,
        'latency_mins' : (end  - start) / 60,
    }

# %%
print(scores_before)

# %%
from llmsearch.tuner import Tuner

cm()
batch_size = 1

tuner_ob = Tuner(
    model = model,
    tokenizer = tokenizer,
    dataset = bm_samples,
    device = 'cuda:0',
    batch_size = batch_size,
    tokenizer_encode_args={'padding': 'longest', 'add_special_tokens' : False},
    tokenizer_decode_args={'spaces_between_special_tokens' : False},
    scorer = get_score,
    prompt_template = langchain.PromptTemplate.from_template("{X}"),
    is_encoder_decoder = False,
    seed = seed,
    column_mapping = {'input_cols' : ["X"],'eval_cols' : ['answer']},
)

# %%
tuner_ob._optimal_batch_size

# %%
print(scores_before)

# %%
scores_before

# %%
# decoder parser is working as expected
# TODO : check scores at different bs then llmsearch

stopping_criteria = StoppingCriteriaList([MultiTokenEOSCriteria(sequence_ids = [32000])])

gen_params1 = {
    'max_new_tokens' : 500,
    'stopping_criteria' : stopping_criteria,
    'generation_seed' : 42,
}

scores_before, outputs_before = tuner_ob.get_score(gen_params1)

scores_before
